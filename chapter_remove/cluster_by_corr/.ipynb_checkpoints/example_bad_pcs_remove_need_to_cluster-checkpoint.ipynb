# %%
# %matplotlib inline
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os

import matplotlib as mpl
mpl.rcParams['font.size']=16
mpl.rcParams['font.serif'] = "Bitstream Vera Serif"
mpl.rcParams['font.family'] = "serif"
import glob
import sys
sys.path.append('/reg/neh/home/qiaoshen/GitHub/loki/src/RingData/')
from DiffCorr import DiffCorr

from matplotlib.gridspec import GridSpec

# %%
def normalize(d, zero=True):
    x=d.copy()
    if zero:
        x-=x.min()
    return x/(x.max()-x.min())

def reshape_unmasked_values_to_shots(shots,mask):
    # this takes vectors of unmasked values, and reshaped this into their masked forms
    # mask is 2D, shots are 1D
    assert(shots.shape[-1]==np.sum(mask) )
    flat_mask = mask.flatten()
    reshaped_shots = np.zeros( (shots.shape[0],mask.size), dtype=shots.dtype)
    
    reshaped_shots[:, flat_mask==1] = shots
    
    return reshaped_shots.reshape((shots.shape[0],mask.shape[0],mask.shape[1]))

def compute_asym(corr, phi_offset=10,num_phi=354, norm = True):
    if norm:
        asym = (normalize_set(corr[:,phi_offset:num_phi/2-phi_offset])\
                      -normalize_set(corr[:,num_phi/2+phi_offset:-phi_offset]) )
    else:
        asym=(corr[:,phi_offset:num_phi/2-phi_offset]\
                      -corr[:,num_phi/2+phi_offset:-phi_offset])\
        /(corr[:,phi_offset:num_phi/2-phi_offset].max()\
          -corr[:,num_phi/2+phi_offset:-phi_offset].min())
        
    return np.mean(asym**2, axis=-1)**0.5

def normalize_set(d):
    x=d.copy()
    x-=x.min(-1)[:,None]
    return x/(x.max(-1)[:,None])

# %%
f = h5py.File('/reg/d/psdm/cxi/cxilp6715/scratch/denoise_polar_intensity/diagnostics/all_pca_maskByRun/GDP_pro/run31_PCA-denoise.h5','r')
var_ratio = f['q%d'%qidx]['explained_variance_ratio'].value

# %%
f_mask = h5py.File('/reg/d/psdm/cxi/cxilp6715/scratch/combined_tables/finer_q/run31.tbl','r')

mask = f_mask['polar_mask_binned'].value
mask = (mask==mask.max())
mask.shape
qs = np.linspace(0,1,mask.shape[0])
dc=DiffCorr(mask[None,:,:],qs,0,pre_dif=True)
mask_cor = dc.autocorr().mean(0)

f_mask.close()

# %%
phi_offset=30
num_phi = 354
exp_cpsi=np.load('/reg/neh/home/qiaoshen/notebooks/OE_figures/exp_cpsi.npy')[:,phi_offset:num_phi/2-phi_offset]
exp_cpsi.shape
# Out:
# (35, 117)

# %%
qidx=19
mpl.rcParams["font.size"]=18
nn=f['q%d'%qidx]['num_pca_cutoff'].value
comps=f['q%d'%qidx]['pca_components']
masked_comps=reshape_unmasked_values_to_shots(comps,mask[qidx][None,:])[:,0,:]
print nn

norm_cors  = []
cors=[]
for ii in range(nn+2):
    
    y = (f['q%d'%qidx]['pca%d'%ii]['train_difcor'][0]/ mask_cor[qidx])[phi_offset:num_phi/2-phi_offset]
    y2 = f['q%d'%qidx]['pca%d'%ii]['train_difcor'][0]/ mask_cor[qidx]
    norm_cors.append(normalize(y) )
    cors.append(y2)
norm_cors=np.array(norm_cors)
cors=np.array(cors)

###comput asym
asym=compute_asym(cors, norm=True, phi_offset=30)
# plt.bar(range(asym.shape[0]),asym)
plt.plot(asym,'o--')

gs = GridSpec(3,2)
plt.figure(figsize=[16,12])
lables=['a','b','c']
for idx,ii in enumerate([0,2,4]):
    plt.subplot(gs[idx,0])
    plt.plot(exp_cpsi[qidx],norm_cors[ii],'k' )
    plt.plot(exp_cpsi[qidx],norm_cors[nn], 'k',linewidth=5, alpha=0.2 )
    plt.title('(%s) -%d eigenimages'%(lables[idx],ii),x=0.5,y=0.85, fontsize=18)
    if idx==2:
        plt.xlabel('$\cos(\psi)$', fontsize = 25)
    if idx==1:
        plt.ylabel('Corraltions (a.u.)', fontsize = 25)
#######################################################################################################
num=3
letters=['d','e']
# fig=plt.figure(figsize=[8,12])
for ii in range(num):
   
    
    if ii==num-1:
        ax=plt.subplot(gs[ii,1])
        plt.plot(asym,'co--')
        plt.title('(f)',x=0.35,y=0.85, fontsize=20)
        plt.xlabel('Number of Eigenimages removed')
        plt.ylabel('Asymmetry (a.u.)', fontsize = 20)
        
        ax.annotate('Minimum', xy=(9, 0.24), xytext=(7.5, 0.28),
            arrowprops=dict(facecolor='black', shrink=0.05),)
    else:
        
        plt.subplot(gs[ii,1])
#         ax=fig.add_subplot(gs[ii,1])
        plt.title('(%s) Eigenimage %d'%(letters[ii],ii+1),x=0.5,y=0.85, fontsize=20)
        plt.plot(comps[ii],'r-',alpha=0.7, linewidth=2)
        if ii==1:
#             plt.xlabel('Pixels')
            plt.text(s='Pixels',x=75, y=-0.65, fontsize=20)
        plt.ylabel('Intensity (a.u.)', fontsize = 20)
# plt.savefig('num_of_pca_corr_maskByRun_44690Shots_q0.53.png',bbox_inches='tight')
# Out:
# 9

# %%
# np.save('/reg/neh/home/qiaoshen/dissertation_notebooks/chapter_remove/cluster_by_corr/all_shots_eignen_q19_normCor.npy',norm_cors[nn])

# %%
num=3
letters=['d','e']
fig=plt.figure(figsize=[8,12])
for ii in range(num):
   
    
    if ii==num-1:
        ax=fig.add_subplot(num,1,ii+1)
        plt.plot(asym,'ko--')
        plt.title('(f)',x=0.35,y=0.85, fontsize=14)
        plt.xlabel('Number of Eigenimages removed')
        plt.ylabel('Asymmetry (a.u.)')
        
        ax.annotate('Minimum', xy=(9, 0.24), xytext=(8, 0.28),
            arrowprops=dict(facecolor='black', shrink=0.05),)
    else:
        
        plt.subplot(num,1,ii+1)
        plt.title('(%s) Eigenimage %d'%(letters[ii],ii+1),x=0.5,y=0.85, fontsize=14)
        plt.plot(comps[ii],'k-',alpha=0.7)
        plt.xlabel('Pixels')
        plt.ylabel('Intensity (a.u.)')
# plt.savefig('eigen_imgs_maskByRun.png',bbox_inches='tight')

# %%
# produced this file in eigen_image/PCA denoised diagnostics-GDP-find elbow by run.ipynb
GDP_diff=np.load('GDPdiff_by_numPCA.npy')
exp_cpsi=np.load('../exp_cpsi.npy')
GDPpro_dir = '/reg/d/psdm/cxi/cxilp6715/scratch/denoise_polar_intensity/diagnostics/all_pca2/GDP_pro/'
GDPpro_num_pca = np.loadtxt(os.path.join(GDPpro_dir,'num_pca_components.txt') )

mask = np.load('/reg/d/psdm/cxi/cxilp6715/results/shared_files/binned_pmask_basic.npy')
qvalue=np.load('../qvalues.npy')

# %%
best_GDP_diff = np.load('../best_GDPdiff_PCAonly.npy')
best_GDP_err = np.load('../best_GDPdiff_err_PCAonly.npy')

# best_GDP_diff = np.load('../best_GDPdiff_PCAonly.npy')
# best_GDP_err = np.load('../best_GDPdiff_err_PCAonly.npy')

# %%
best_GDP_diff.shape
exp_cpsi.shape

# %%
plt.figure(figsize=[8,12])
num_phi = GDP_diff.shape[-1]
phi_offset=30
qidx = 17
plt.subplot(311)
nn=0
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(GDP_diff[qidx][nn, phi_offset:num_phi/2-phi_offset]),
         'k-', markersize=8)
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(best_GDP_diff[qidx, phi_offset:num_phi/2-phi_offset])
         ,'-', linewidth=5, alpha=0.3, c='k')
plt.title('(a)',x=0.05,y=0.85)
plt.xlabel('$\cos(\Psi)$')
plt.ylabel('Corraltions (a.u.)')


plt.subplot(312)
nn=1
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(GDP_diff[qidx][nn, phi_offset:num_phi/2-phi_offset])
         ,'k-', markersize=8)
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(best_GDP_diff[qidx, phi_offset:num_phi/2-phi_offset])
         ,'-', linewidth=5, alpha=0.3, c='k')
plt.title('(b)',x=0.05,y=0.85)
plt.xlabel('$\cos(\Psi)$')
plt.ylabel('Corraltions (a.u.)')


plt.subplot(313)
nn=2
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(GDP_diff[qidx][nn, phi_offset:num_phi/2-phi_offset]),
         'k-', markersize=8)
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(best_GDP_diff[qidx, phi_offset:num_phi/2-phi_offset])
         ,'-', linewidth=5, alpha=0.3, c='k')
plt.title('(c)',x=0.05,y=0.85)
plt.xlabel('$\cos(\Psi)$')
plt.ylabel('Corraltions (a.u.)')
print qvalue[qidx]

# plt.savefig('num_of_pca_corr.png',bbox_inches='tight')

# %%
GDPpro_list_all=glob.glob(os.path.join(GDPpro_dir,'run*_PCA-denoise.h5'))
f=h5py.File(GDPpro_list_all[10],'r')
comps=f['q%d'%qidx]['pca_components']
var_ratio = f['q%d'%qidx]['explained_variance_ratio'].value
masked_comps=reshape_unmasked_values_to_shots(comps,mask[qidx][None,:])[:,0,:]

# %%
num=3
letters=['d','e']
plt.figure(figsize=[8,12])
for ii in range(num):
   
    
    if ii==num-1:
        plt.subplot(num,1,ii+1)
        plt.plot(var_ratio[:20],'ko')
        plt.title('(f) Explained variance ratio',x=0.4,y=0.85)
        plt.xlabel('Eigen image number')
        plt.ylabel('Ratio')
    else:
        
        plt.subplot(num,1,ii+1)
        plt.title('(%s) Eigen image %d'%(letters[ii],ii+1),x=0.3,y=0.85)
        plt.plot(masked_comps[ii],'k-',alpha=0.7)
        plt.xlabel('Pixels')
        plt.ylabel('Intensity (a.u.)')
# plt.savefig('eigen_imgs.png',bbox_inches='tight')

# %%
asym=compute_asym(GDP_diff[qidx], phi_offset=phi_offset)
plt.figure(figsize=[12,4])
plt.subplot(121)
plt.plot(asym,'o')
plt.subplot(122)
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(GDP_diff[qidx,18][phi_offset:num_phi/2-phi_offset]) )
plt.plot(exp_cpsi[qidx-10,phi_offset:-phi_offset],normalize(GDP_diff[qidx,6][phi_offset:num_phi/2-phi_offset]) )

# %%
p

# %%
comps.shape
